# %% [markdown]
# #### 1. Read the two cars datasets

# %%
import pandas as pd
dt_1 = pd.read_csv('C:/Users/ACER/Downloads/cars1.csv')
dt_2 = pd.read_csv('C:/Users/ACER/Downloads/cars2.csv')

# %%
dt_1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
dt_2
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# ...

# %% [markdown]
# #### 2. Remove the blank columns from the first dataset

# %%
dt_1 = dt_1.dropna(axis = 'columns')

# %% [markdown]
# #### 3. Join two datasets

# %%
dataset = dt_1.append(dt_2)

# %% [markdown]
# #### 4. Find the number of cars weighing more than 3000

# %%
condition = dataset[dataset['weight']>3000]
len(condition)
# Out:
# 168

# %% [markdown]
# #### 5. Get the rows with "Ford" in its name

# %%
car_name='Ford'.lower()
c = dataset.loc[dataset['car'].str.contains(car_name, case=False)]
c
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 17   21.0          6           200         85    2587          16.0     70
# 25   10.0          8           360        215    4615          14.0     70
# 32   25.0          4            98          ?    2046          19.0     71
# 36   19.0          6           250         88    3302          15.5     71
# 40   14.0          8           351        153    4154          13.5     71
# 43   13.0          8           400        170    4746          12.0     71
# 48   18.0          6           250         88    3139          14.5     71
# 61   21.0          4           122         86    2226          16.5     72
# 65   14.0          8           351        153    4129          13.0     72
# ...

# %% [markdown]
# #### 6. Find the maximum acceleration for each number of cylinders

# %%
dataset_1 = dataset.groupby('cylinders')
dataset_1.max(dataset_1['acceleration'])
# Out:
#             mpg  displacement  weight  acceleration  model  origin
# cylinders
# 3          23.7            80    2720          13.5     80       3
# 4          46.6           156    3270          24.8     82       3
# 5          36.4           183    3530          20.1     80       2
# 6          38.0           262    3907          21.0     82       3
# 8          26.6           455    5140          22.2     81       1

# %% [markdown]
# #### 7. Find the number of unique models

# %%
dataset['model'].unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], dtype=int64)

# %%
dataset['model'].nunique()
# Out:
# 13

# %% [markdown]
# #### 8. Find the minimum, 25th percentile, median, 75th, and maximum for the weight

# %%
dataset['weight'].describe()
# Out:
# count     398.000000
# mean     2970.424623
# std       846.841774
# min      1613.000000
# 25%      2223.750000
# 50%      2803.500000
# 75%      3608.000000
# max      5140.000000
# Name: weight, dtype: float64

# %%
print('Maximum weight:',dataset['weight'].max())
print('Minimum weight:',dataset['weight'].min())
print('25% quantile:',dataset['weight'].quantile(q=0.25))
print('Median:'  , dataset['weight'].median())
print('75% quantile:' ,dataset['weight'].quantile(q=0.75))
# Out:
# Maximum weight: 5140
# Minimum weight: 1613
# 25% quantile: 2223.75
# Median: 2803.5
# 75% quantile: 3608.0

# %% [markdown]
# #### 9. Bin the weight into quartiles and replace the values with the bin name

# %%
pd.qcut(dataset['weight'], 4)
# Out:
# 0         (2803.5, 3608.0]
# 1         (3608.0, 5140.0]
# 2         (2803.5, 3608.0]
# 3         (2803.5, 3608.0]
# 4         (2803.5, 3608.0]
#               ...
# 195      (2223.75, 2803.5]
# 196    (1612.999, 2223.75]
# 197      (2223.75, 2803.5]
# 198      (2223.75, 2803.5]
# 199      (2223.75, 2803.5]
# Name: weight, Length: 398, dtype: category
# Categories (4, interval[float64, right]): [(1612.999, 2223.75] < (2223.75, 2803.5] < (2803.5, 3608.0] < (3608.0, 5140.0]]

# %%
pd.qcut(dataset['weight'], 4, labels=["Q1", "Median", "Q3",'Max'])
# Out:
# 0          Q3
# 1         Max
# 2          Q3
# 3          Q3
# 4          Q3
#         ...
# 195    Median
# 196        Q1
# 197    Median
# 198    Median
# 199    Median
# Name: weight, Length: 398, dtype: category
# Categories (4, object): ['Q1' < 'Median' < 'Q3' < 'Max']

# %% [markdown]
# #### 10. Find the frequency for each model

# %%
frequency = dataset['model'].value_counts()
frequency
# Out:
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 70    29
# 79    29
# 80    29
# 81    29
# 71    28
# 72    28
# 77    28
# 74    27
# Name: model, dtype: int64

# %% [markdown]
# #### 11. Get the number of missing values for each column

# %%
dataset.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model           0
# origin          0
# car             0
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model           0
# origin          0
# car             0
# dtype: int64

# %% [markdown]
# #### 12. Find average and max weight for each number of cylinders

# %%
print(dataset.groupby('cylinders').mean()['weight'])
# Out:
# cylinders
# 3    2398.500000
# 4    2308.127451
# 5    3103.333333
# 6    3198.226190
# 8    4114.718447
# Name: weight, dtype: float64

# %%
print(dataset.groupby('cylinders').max()['weight'])
# Out:
# cylinders
# 3    2720
# 4    3270
# 5    3530
# 6    3907
# 8    5140
# Name: weight, dtype: int64

# %% [markdown]
# #### 13. Get the horsepower value of 30th Ford car

# %%
ford_car = dataset.loc[dataset['car'].str.contains('ford', case=False)]
ford_car['horsepower'].iloc[29]
# Out:
# '78'

# %% [markdown]
# #### 14. Change all Chevrolet cars' name to only "Chevrolet"

# %%
dataset.loc[dataset['car'].str.contains('chevrolet'), 'car'] = 'chevrolet'
dataset
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         1           chevrolet
# ...

# %% [markdown]
# #### 15. Make relevant pandas change to be able to see all rows of the dataset

# %%
pd.options.display.max_rows=398

# %%
dataset.reset_index()
# Out:
#      index   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0        0  18.0          8           307        130    3504          12.0
# 1        1  15.0          8           350        165    3693          11.5
# 2        2  18.0          8           318        150    3436          11.0
# 3        3  16.0          8           304        150    3433          12.0
# 4        4  17.0          8           302        140    3449          10.5
# 5        5  15.0          8           429        198    4341          10.0
# 6        6  14.0          8           454        220    4354           9.0
# 7        7  14.0          8           440        215    4312           8.5
# 8        8  14.0          8           455        225    4425          10.0
# 9        9  15.0          8           390        190    3850           8.5
# 10      10  15.0          8           383        170    3563          10.0
# ...

# %%
dataset.shape
# Out:
# (398, 9)
